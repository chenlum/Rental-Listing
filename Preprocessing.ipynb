# %%
import numpy as np 
import pandas as pd 
import json
import re

# %%
train_df = pd.read_json('processed_train.json')
test_df = pd.read_json('processed_test.json')
train_df.head(30)
# Out:
#         bathrooms  bedrooms                       building_id        created  \
# 10            1.5         3  53a5b119ba8f7b61d4e010512e0dfc85  1466754864000
# 10000         1.0         2  c5c8a357cba207596b04d1afd1e4f130  1465733967000
# 100004        1.0         1  c3ba40552e2120b0acfc3cb5730bb2aa  1460863601000
# 100007        1.0         1  28d9ad350afeaab8027513a3e52ac8d5  1460946122000
# 100013        1.0         4                                 0  1461807161000
# 100014        2.0         4  38a913e46c94a7f46ddf19b756a9640c  1461039887000
# 100016        1.0         2  3ba49a93260ca5df92fde024cb4ca61f  1461727196000
# 100020        2.0         1  0372927bcb6a0949613ef5bf893bbac7  1460527302000
# 100026        1.0         1  a7efbeb58190aa267b4a9121cd0c88c0  1461119795000
# 100027        2.0         4                                 0  1459565895000
# 100030        1.0         0                                 0  1460596230000
# 10004         1.0         1                                 0  1464924082000
# 100044        1.0         2  67c9b420da4a365bc26a6cd0ef4a5320  1461044245000
# 100048        2.0         2                                 0  1460164931000
# 10005         1.0         1                                 0  1464750661000
# 100051        1.0         0  bfb9405149bfff42a92980b594c28234  1460946960000
# 100052        1.0         2  642cc2c920512ffe2a74c28122f8b47f  1461304636000
# 100053        1.0         1                                 0  1461036988000
# 100055        1.0         4  cc4c6ae9225df6d2395c4e16c235f7ab  1461124832000
# 100058        1.0         1  dc3cae15729b48fec3394f9295671991  1460173782000
# 100062        1.0         3  205f95d4a78f1f3befda48b89edc9669  1460428785000
# 100063        1.0         2  ecea86b79afa539505aa4bad3ff449c6  1459995105000
# 100065        1.0         1  1a6cf9b71da65cdc0cfd5015a75317ac  1460524663000
# 100066        1.0         1  a6200d7448037cfee809b2451219f879  1460860012000
# 10007         2.0         4  05b871a1e1e0368391160bcefc608e00  1465274396000
# 100071        3.0         4  45b4143a9841eb63d7203c4f21a64ff7  1461739420000
# 100075        1.0         1  d68497ff1f5ac77f143e5f21817ed6fb  1461551390000
# 100076        1.0         1  ec447453d3b8033e14a7b54ba1e13e02  1461303550000
# 100079        1.0         1  f06ad2f6f1a821c8efc03dc195d369df  1461216430000
# 100081        2.0         2  f115a9bff3a9c4e6eedc9114374b3d74  1461639577000
#
#                                               description  \
# 10      A Brand New 3 Bedroom 1.5 bath ApartmentEnjoy ...
# 10000
# 100004  Top Top West Village location, beautiful Pre-w...
# 100007  Building Amenities - Garage - Garden - fitness...
# 100013  Beautifully renovated 3 bedroom flex 4 bedroom...
# 100014
# 100016  Stunning unit with a great location and lots o...
# 100020  This huge sunny ,plenty of lights 1 bed/2 bath...
# 100026                           <p><a  website_redacted
# 100027  This is a spacious four bedroom with every bed...
# 100030  New to the market! Spacious studio located in ...
# 10004   Check out this one bedroom apartment in a grea...
# 100044  ***LOW FEE. Beautiful CHERRY OAK WOODEN FLOORS...
# 100048  Lincoln Square's premier full service building...
# 10005   Spacious 1-Bedroom to fit King-sized bed comfo...
# 100051  Stunning  full renovated studio unit. High cei...
# 100052  East Village is a great community with great p...
# 100053  *Location: Thayer St. &amp; Broadway, Manhatta...
# 100055
# 100058
# 100062  BEAUTIFUL 2 BEDROOM POSSIBLE CONVERSION INTO T...
# 100063  No fee huge two bedroom apartment. Great locat...
# 100065
# 100066  CooperCooper.com :: Web ID #179546; Access 100...
# 10007   SPRAWLING 2 BEDROOM FOUND! ENJOY THE LUXURY OF...
# 100071  Amazing 4 bedroom convertible. Remarkably luxu...
# 100075  Don't miss out on this fantastic apartment.......
# 100076  The TRUE 1 bedroom apartment features extra la...
# 100079          Currently under renovation, this one b...
# 100081  Gut Renovated Apartment with Stainless steel a...
#
#             display_address  \
# 10      Metropolitan Avenue
# 10000       Columbus Avenue
# 100004          W 13 Street
# 100007     East 49th Street
# 100013    West 143rd Street
# 100014     West 18th Street
# 100016    West 107th Street
# 100020     West 21st Street
# 100026     Hamilton Terrace
# 100027           522 E 11th
# 100030          York Avenue
# 10004       W. 173rd Street
# 100044            E 38th St
# 100048     West 63rd Street
# 10005        East 56th St..
# 100051     East 34th Street
# 100052             1st Ave.
# 100053            Thayer St
# 100055    West 106th Street
# 100058           1st Avenue
# 100062       Madison Avenue
# 100063           E 30th St,
# 100065     East 35th Street
# 100066       Liberty Street
# 10007              W 18 St.
# 100071            East 56th
# 100075           E 81st St.
# 100076     West 57th Street
# 100079   1215 Morris Avenue
# 100081           E 79th St.
#
#                                                  features  latitude  \
# 10                                                     []   40.7145
# 10000   [Doorman, Elevator, Fitness Center, Cats Allow...   40.7947
# 100004  [Laundry In Building, Dishwasher, Hardwood Flo...   40.7388
# 100007                          [Hardwood Floors, No Fee]   40.7539
# 100013                                          [Pre-War]   40.8241
# 100014                                                 []   40.7429
# 100016  [prewar, elevator, Dogs Allowed, Cats Allowed,...   40.8012
# 100020  [Doorman, Elevator, Pre-War, Terrace, Laundry ...   40.7427
# 100026  [Cats Allowed, Dogs Allowed, Elevator, Laundry...   40.8234
# 100027                      [Dishwasher, Hardwood Floors]   40.7278
# 100030                                                 []   40.7769
# 10004   [prewar, dishwasher, HIGHRISE, ROOFDECK, EAT I...   40.8448
# 100044   [Doorman, Elevator, Laundry in Building, No Fee]   40.7488
# 100048  [Swimming Pool, Doorman, Fitness Center, No Fe...   40.7707
# 10005   [Elevator, Multi-Level, Laundry in Building, D...   40.7584
# 100051  [Doorman, Elevator, Fitness Center, Laundry in...   40.7439
# 100052                                  [Hardwood Floors]   40.7305
# 100053  [prewar, LOWRISE, EAT IN KITCHEN, SIMPLEX, HAR...   40.8643
# 100055               [No Fee, Cats Allowed, Dogs Allowed]   40.7999
# 100058                       [Cats Allowed, Dogs Allowed]   40.7328
# 100062   [Doorman, Elevator, Dishwasher, Hardwood Floors]   40.7454
# 100063  [Elevator, Central A/C, Walk in Closet(s), Par...   40.7427
# 100065                       [Cats Allowed, Dogs Allowed]   40.7447
# 100066  [Doorman, Fitness Center, Pool, Elevator, Publ...   40.7074
# 10007   [Balcony, Doorman, Elevator, Fitness Center, T...   40.7391
# 100071  [Roof Deck, Dining Room, Balcony, Doorman, Ele...   40.7584
# 100075              [Dishwasher, Hardwood Floors, No Fee]   40.7728
# 100076  [Roof Deck, Doorman, Elevator, Laundry in Buil...   40.7709
# 100079                                                 []   40.8335
# 100081  [Doorman, Elevator, Fitness Center, Pre-War, L...   40.7716
#
#         listing_id  longitude      ...      des_capital tele_count  web_count  \
# 10         7211212   -73.9425      ...                0          1          0
# 10000      7150865   -73.9667      ...                0          0          0
# 100004     6887163   -74.0018      ...                0          0          0
# 100007     6888711   -73.9677      ...                1          0          0
# 100013     6934781   -73.9493      ...                0          0          0
# 100014     6894514   -74.0028      ...                0          0          0
# 100016     6930771   -73.9660      ...                0          2          0
# 100020     6867392   -73.9957      ...                3          0          0
# 100026     6898799   -73.9457      ...                0          0          0
# 100027     6814332   -73.9808      ...                0          0          1
# 100030     6869199   -73.9467      ...                0          0          0
# 10004      7102986   -73.9396      ...                1          2          0
# 100044     6895442   -73.9770      ...               69          1          0
# 100048     6846213   -73.9817      ...                2          0          0
# 10005      7089402   -73.9648      ...                3          1          0
# 100051     6889043   -73.9743      ...                5          1          0
# 100052     6913348   -73.9830      ...                0          0          0
# 100053     6894111   -73.9280      ...                5          1          1
# 100055     6900220   -73.9638      ...                0          0          0
# 100058     6848536   -73.9799      ...                0          0          0
# 100062     6858062   -73.9845      ...               14          0          0
# 100063     6836760   -73.9794      ...                1          0          0
# 100065     6866830   -73.9741      ...                0          0          0
# 100066     6885927   -74.0081      ...                9          1          0
# 10007      7120132   -73.9936      ...               98          1          0
# 100071     6933499   -73.9653      ...                9          0          0
# 100075     6921632   -73.9502      ...               21          1          0
# 100076     6913084   -73.9917      ...                1          0          0
# 100079     6907079   -73.9141      ...                0          0          0
# 100081     6925264   -73.9506      ...                0          1          0
#
#        email_count building_id_exist       date  month  day_of_week  hour  \
# 10               0              True 2016-06-24      6       Friday     7
# 10000            0              True 2016-06-12      6       Sunday    12
# 100004           0              True 2016-04-17      4       Sunday     3
# 100007           0              True 2016-04-18      4       Monday     2
# 100013           0             False 2016-04-28      4     Thursday     1
# 100014           0              True 2016-04-19      4      Tuesday     4
# 100016           2              True 2016-04-27      4    Wednesday     3
# 100020           0              True 2016-04-13      4    Wednesday     6
# 100026           0              True 2016-04-20      4    Wednesday     2
# 100027           0             False 2016-04-02      4     Saturday     2
# 100030           0             False 2016-04-14      4     Thursday     1
# 10004            2             False 2016-06-03      6       Friday     3
# 100044           1              True 2016-04-19      4      Tuesday     5
# 100048           0             False 2016-04-09      4     Saturday     1
# 10005            0             False 2016-06-01      6    Wednesday     3
# 100051           1              True 2016-04-18      4       Monday     2
# 100052           0              True 2016-04-22      4       Friday     5
# 100053           2             False 2016-04-19      4      Tuesday     3
# 100055           0              True 2016-04-20      4    Wednesday     4
# 100058           0              True 2016-04-09      4     Saturday     3
# 100062           0              True 2016-04-12      4      Tuesday     2
# 100063           0              True 2016-04-07      4     Thursday     2
# 100065           0              True 2016-04-13      4    Wednesday     5
# 100066           1              True 2016-04-17      4       Sunday     2
# 10007            1              True 2016-06-07      6      Tuesday     4
# 100071           1              True 2016-04-27      4    Wednesday     6
# 100075           0              True 2016-04-25      4       Monday     2
# 100076           0              True 2016-04-22      4       Friday     5
# 100079           0              True 2016-04-21      4     Thursday     5
# 100081           1              True 2016-04-26      4      Tuesday     2
#
#         interest_num
# 10                 2
# 10000              3
# 100004             1
# 100007             3
# 100013             3
# 100014             2
# 100016             3
# 100020             3
# 100026             2
# 100027             3
# 100030             3
# 10004              3
# 100044             1
# 100048             3
# 10005              3
# 100051             2
# 100052             3
# 100053             3
# 100055             3
# 100058             3
# 100062             3
# 100063             2
# 100065             3
# 100066             3
# 10007              2
# 100071             3
# 100075             2
# 100076             3
# 100079             1
# 100081             3
#
# [30 rows x 28 columns]

# %%
def basic_clean(text):
    clean_text = re.sub(r'[^\w ]+', '', text)  
    return clean_text.lower()

# %%
from nltk.stem import WordNetLemmatizer
wnl = WordNetLemmatizer()

def stem_words(text):
    words = basic_clean(text).split()
    clean_text = ''
    # stem verbs
    verb_stem = []
    for word in words:
        verb_stem.append(wnl.lemmatize(word, 'v'))
    # stem nouns
    stemmed_words = []
    for word in verb_stem:
        stemmed_words.append(wnl.lemmatize(word, 'n'))
    for word in stemmed_words:
        clean_text = ' '.join([clean_text, "".join(word)]) 
    return clean_text

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
stop_words = set(stopwords.words('english')) 

def remove_stopwords(text):
    text = stem_words(text)
    word_tokens = word_tokenize(text) 
    clean_text = ''
    for w in word_tokens: 
        if w not in stop_words: 
            clean_text = ' '.join([clean_text, "".join(w)])        
    return clean_text

# %%
def clean_desc(text):
    text = remove_stopwords(text)
    desc_text = ''
    desc = text.lower().strip()
    desc = re.sub(r'[\w]*/|<\w+ */*>*', ' ', desc)
    desc_text = ' '.join([desc_text, desc])
    return desc_text

# %%
def clean_ft(feature):
    ft_text = ''
    if feature != []:
        for text in feature:
            text = basic_clean(text)
            ft_text = "|".join([ft_text, ' '.join(text.strip().lower().split(" "))])
    return ft_text

# %%
# clean description and feature 
train_df['description'] = train_df['description'].apply(clean_desc)
train_df['features'] = train_df['features'].apply(clean_ft)
test_df['description'] = test_df['description'].apply(clean_desc)
test_df['features'] = test_df['features'].apply(clean_ft)
train_df
# Out:
#         bathrooms  bedrooms                       building_id        created  \
# 10            1.5         3  53a5b119ba8f7b61d4e010512e0dfc85  1466754864000
# 10000         1.0         2  c5c8a357cba207596b04d1afd1e4f130  1465733967000
# 100004        1.0         1  c3ba40552e2120b0acfc3cb5730bb2aa  1460863601000
# 100007        1.0         1  28d9ad350afeaab8027513a3e52ac8d5  1460946122000
# 100013        1.0         4                                 0  1461807161000
# 100014        2.0         4  38a913e46c94a7f46ddf19b756a9640c  1461039887000
# 100016        1.0         2  3ba49a93260ca5df92fde024cb4ca61f  1461727196000
# 100020        2.0         1  0372927bcb6a0949613ef5bf893bbac7  1460527302000
# 100026        1.0         1  a7efbeb58190aa267b4a9121cd0c88c0  1461119795000
# 100027        2.0         4                                 0  1459565895000
# 100030        1.0         0                                 0  1460596230000
# 10004         1.0         1                                 0  1464924082000
# 100044        1.0         2  67c9b420da4a365bc26a6cd0ef4a5320  1461044245000
# 100048        2.0         2                                 0  1460164931000
# 10005         1.0         1                                 0  1464750661000
# 100051        1.0         0  bfb9405149bfff42a92980b594c28234  1460946960000
# 100052        1.0         2  642cc2c920512ffe2a74c28122f8b47f  1461304636000
# 100053        1.0         1                                 0  1461036988000
# 100055        1.0         4  cc4c6ae9225df6d2395c4e16c235f7ab  1461124832000
# 100058        1.0         1  dc3cae15729b48fec3394f9295671991  1460173782000
# 100062        1.0         3  205f95d4a78f1f3befda48b89edc9669  1460428785000
# 100063        1.0         2  ecea86b79afa539505aa4bad3ff449c6  1459995105000
# 100065        1.0         1  1a6cf9b71da65cdc0cfd5015a75317ac  1460524663000
# 100066        1.0         1  a6200d7448037cfee809b2451219f879  1460860012000
# 10007         2.0         4  05b871a1e1e0368391160bcefc608e00  1465274396000
# 100071        3.0         4  45b4143a9841eb63d7203c4f21a64ff7  1461739420000
# 100075        1.0         1  d68497ff1f5ac77f143e5f21817ed6fb  1461551390000
# 100076        1.0         1  ec447453d3b8033e14a7b54ba1e13e02  1461303550000
# 100079        1.0         1  f06ad2f6f1a821c8efc03dc195d369df  1461216430000
# 100081        2.0         2  f115a9bff3a9c4e6eedc9114374b3d74  1461639577000
# ...           ...       ...                               ...            ...
# 99915         1.0         1                                 0  1461546817000
# 99917         1.0         1  e243886a4cac69881c07c6a1f38185bf  1461645794000
# 99919         1.0         0  da2f861e30b1391e8368438efddaa2a7  1460094717000
# 99921         1.0         2  fc0676a4d4fdb4e767faf6414975a0cb  1461942209000
# 99923         2.0         2                                 0  1459818765000
# 99924         1.0         1  93cd24891f8423d45ac587ab1fdb1225  1461467718000
# 99931         1.0         1                                 0  1461547223000
# 99933         1.0         2  80a120d6bc3aba97f40fee8c2204524b  1459655481000
# 99935         1.0         1                                 0  1461034735000
# 99937         1.5         0  d48767c37a934daaf0bbb0e58c755d0c  1460612373000
# 9994          1.0         2                                 0  1465176164000
# 99953         1.0         1  e243886a4cac69881c07c6a1f38185bf  1461637096000
# 99956         2.0         2                                 0  1460824790000
# 99960         1.0         1  6f1e2020bd0e4ff48d3a5d482944a753  1459830932000
# 99961         2.0         3  ae3e5e3d93ea18140752078f9a3177af  1461294704000
# 99964         1.0         0  f8009151babfad197b48f6922eec99f2  1461907249000
# 99965         2.0         3  a485c2deb62ad3c9c76edebd532a446c  1459661003000
# 99966         1.0         3  a36895b9975c6991ca0fa1d9a99023a1  1460698599000
# 99979         1.0         1  e4490b8e6a410d39d38e40e572243a64  1460604744000
# 99980         1.0         0  d16f875956b264d5920d8424631091d4  1461761532000
# 99982         1.0         1  6134e7c4dd1a98d9aee36623c9872b49  1459996140000
# 99984         1.0         1  8e7bd3cbdd67a0dcc719224a41699d2b  1459567023000
# 99986         1.0         1  399f92c2a78ada2f01c8414ce3bc909b  1460605182000
# 99987         1.0         1                                 0  1460345345000
# 99988         1.0         1  3b13a6597596619bdbc8281096f21d23  1461339851000
# 9999          1.0         2  297160caf8a88c10718b492d4672c6b4  1464846065000
# 99991         1.0         1  9e871ccfea7b07686c101548ca693af6  1459794154000
# 99992         1.0         1  7967a1280bf3f7644500fc79d2696b0e  1460772820000
# 99993         1.0         0  ad67f6181a49bde19218929b401b31b7  1460081613000
# 99994         1.0         2  5173052db6efc0caaa4d817112a70f32  1460429287000
#
#                                               description  \
# 10       brand new 3 bedroom 15 bath apartmentenjoy fo...
# 10000
# 100004   top top west village location beautiful prewa...
# 100007   build amenity garage garden fitness room laun...
# 100013   beautifully renovate 3 bedroom flex 4 bedroom...
# 100014
# 100016   stun unit great location lot natural light cl...
# 100020   huge sunny plenty light 1 bed2 bath offer bra...
# 100026                                pa website_redacted
# 100027   spacious four bedroom every bedroom able fit ...
# 100030   new market spacious studio locate 80 well mai...
# 10004    check one bedroom apartment great location wa...
# 100044   low fee beautiful cherry oak wooden floorsthe...
# 100048   lincoln square premier full service build loc...
# 10005    spacious 1bedroom fit kingsized bed comfortab...
# 100051   stun full renovate studio unit high ceiling s...
# 100052   east village great community great people off...
# 100053   location thayer st amp broadway manhattanthis...
# 100055
# 100058
# 100062   beautiful 2 bedroom possible conversion three...
# 100063   fee huge two bedroom apartment great location...
# 100065
# 100066   coopercoopercom web id 179546 access 1000 uni...
# 10007    sprawl 2 bedroom find enjoy luxury full servi...
# 100071   amaze 4 bedroom convertible remarkably luxuri...
# 100075   dont miss fantastic apartmentspacious 1bdr af...
# 100076   true 1 bedroom apartment feature extra large ...
# 100079   currently renovation one bedroom go beautiful...
# 100081   gut renovate apartment stainless steel applia...
# ...                                                   ...
# 99915    elegant spacious one bedroom modern luxury bu...
# 99917
# 99919    important notice plan move next 15 day please...
# 99921    washer dryer unit 5 minute walk r train brigh...
# 99923    tremendous classic six luxurious prewar doorm...
# 99924    luxury live fulltime doorman concierge servic...
# 99931    one block form washington square park new gut...
# 99933    residence feature stainless steal appliance n...
# 99935    newly renovate 1 bedroom unit recently renova...
# 99937    bedroom top live room bottombr br awesome spa...
# 9994     dont miss spacious beautiful upper west side ...
# 99953    exquisitely appoint 1 bedroom 1 bath residenc...
# 99956    spacious two bedroom apartment feature energy...
# 99960    great lower east side one bedroomwell maintai...
# 99961    large spacious 3 bdone ba apartment hardwood ...
# 99964    77th st fully gut renov studio hi ceil xpsd b...
# 99965    fulltime doorman pet friendlyelevator gymlaun...
# 99966    great opportunity rent excellent 2 bed flex 3...
# 99979
# 99980    incredibly sunny spacious studio apartment lu...
# 99982    luxury build midtown west 24 hr doorman close...
# 99984    huge true king size one bedroom elevator buil...
# 99986    charm one bedroom hardwood floor sunny clean ...
# 99987    89th park ave block central park huge kitchen...
# 99988    24hr doorman luxury build heart east village ...
# 9999     30th3rd massive conv 2br luxury full service ...
# 99991    high end condo finish swim pool king size bed...
# 99992    large renovate one bedroom apartment stainles...
# 99993    stylishly sleek studio apartment unsurpassed ...
# 99994    look giant 2 bedroom apartment locate soughta...
#
#             display_address  \
# 10      Metropolitan Avenue
# 10000       Columbus Avenue
# 100004          W 13 Street
# 100007     East 49th Street
# 100013    West 143rd Street
# 100014     West 18th Street
# 100016    West 107th Street
# 100020     West 21st Street
# 100026     Hamilton Terrace
# 100027           522 E 11th
# 100030          York Avenue
# 10004       W. 173rd Street
# 100044            E 38th St
# 100048     West 63rd Street
# 10005        East 56th St..
# 100051     East 34th Street
# 100052             1st Ave.
# 100053            Thayer St
# 100055    West 106th Street
# 100058           1st Avenue
# 100062       Madison Avenue
# 100063           E 30th St,
# 100065     East 35th Street
# 100066       Liberty Street
# 10007              W 18 St.
# 100071            East 56th
# 100075           E 81st St.
# 100076     West 57th Street
# 100079   1215 Morris Avenue
# 100081           E 79th St.
# ...                     ...
# 99915     North 10th Street
# 99917             W 58th St
# 99919      East 78th Street
# 99921          Ridge Blvd.
# 99923      West 81st Street
# 99924            8th Avenue
# 99931       Thompson Street
# 99933                 Water
# 99935      East 12th Street
# 99937           York Avenue
# 9994       West 98th Street
# 99953      West 58th Street
# 99956         Nassau Street
# 99960         Baxter Street
# 99961       East 3rd Street
# 99964               E 77 St
# 99965      East 87th Street
# 99966      East 72nd Street
# 99979             Eldert St
# 99980           John Street
# 99982              W 54 St.
# 99984           E 76 Street
# 99986        Charles Street
# 99987      East 89th Street
# 99988      East 10th Street
# 9999                E 30 St
# 99991             Rector Pl
# 99992      West 45th Street
# 99993           Wall Street
# 99994     Park Terrace East
#
#                                                  features  latitude  \
# 10                                                          40.7145
# 10000   |doorman|elevator|fitness center|cats allowed|...   40.7947
# 100004  |laundry in building|dishwasher|hardwood floor...   40.7388
# 100007                            |hardwood floors|no fee   40.7539
# 100013                                            |prewar   40.8241
# 100014                                                      40.7429
# 100016  |prewar|elevator|dogs allowed|cats allowed|low...   40.8012
# 100020  |doorman|elevator|prewar|terrace|laundry in un...   40.7427
# 100026  |cats allowed|dogs allowed|elevator|laundry in...   40.8234
# 100027                        |dishwasher|hardwood floors   40.7278
# 100030                                                      40.7769
# 10004   |prewar|dishwasher|highrise|roofdeck|eat in ki...   40.8448
# 100044       |doorman|elevator|laundry in building|no fee   40.7488
# 100048  |swimming pool|doorman|fitness center|no fee|d...   40.7707
# 10005   |elevator|multilevel|laundry in building|dishw...   40.7584
# 100051  |doorman|elevator|fitness center|laundry in bu...   40.7439
# 100052                                   |hardwood floors   40.7305
# 100053    |prewar|lowrise|eat in kitchen|simplex|hardwood   40.8643
# 100055                  |no fee|cats allowed|dogs allowed   40.7999
# 100058                         |cats allowed|dogs allowed   40.7328
# 100062       |doorman|elevator|dishwasher|hardwood floors   40.7454
# 100063  |elevator|central ac|walk in closets|parking|h...   40.7427
# 100065                         |cats allowed|dogs allowed   40.7447
# 100066  |doorman|fitness center|pool|elevator|publicou...   40.7074
# 10007   |balcony|doorman|elevator|fitness center|terra...   40.7391
# 100071  |roof deck|dining room|balcony|doorman|elevato...   40.7584
# 100075                 |dishwasher|hardwood floors|no fee   40.7728
# 100076  |roof deck|doorman|elevator|laundry in buildin...   40.7709
# 100079                                                      40.8335
# 100081  |doorman|elevator|fitness center|prewar|laundr...   40.7716
# ...                                                   ...       ...
# 99915   |swimming pool|doorman|fitness center|dogs all...   40.7176
# 99917   |cats allowed|dogs allowed|doorman|elevator|de...   40.7655
# 99919   |elevator|laundry in building|laundry in unit|...   40.7721
# 99921                          |furnished|laundry in unit   40.6182
# 99923           |doorman|prewar|dogs allowed|cats allowed   40.7829
# 99924   |doorman|laundry in building|laundry in unit|d...   40.7637
# 99931                          |dogs allowed|cats allowed   40.7293
# 99933   |roof deck|dining room|doorman|elevator|fitnes...   40.7075
# 99935                                                       40.7287
# 99937   |prewar|laundry in building|dishwasher|hardwoo...   40.7769
# 9994            |doorman|prewar|dogs allowed|cats allowed   40.7957
# 99953   |doorman|elevator|furnished|prewar|dishwasher|...   40.7655
# 99956   |common outdoor space|cats allowed|dogs allowe...   40.7095
# 99960                                    |hardwood floors   40.7179
# 99961   |doorman|elevator|laundry in building|dishwash...   40.7222
# 99964         |loft|multilevel|dishwasher|hardwood floors   40.7708
# 99965   |swimming pool|dining room|doorman|elevator|la...   40.7766
# 99966   |roof deck|doorman|elevator|fitness center|lof...   40.7695
# 99979                                                       40.6865
# 99980   |common outdoor space|cats allowed|dogs allowe...   40.7090
# 99982   |doorman|elevator|fitness center|laundry in bu...   40.7645
# 99984   |elevator|multilevel|dishwasher|hardwood floor...   40.7728
# 99986                           |elevator|hardwood floors   40.7350
# 99987                                         |dishwasher   40.7889
# 99988   |cats allowed|no fee|doorman|elevator|laundry ...   40.7296
# 9999    |elevator|laundry in building|laundry in unit|...   40.7426
# 99991   |common outdoor space|cats allowed|dogs allowe...   40.7102
# 99992   |doorman|elevator|prewar|dogs allowed|cats all...   40.7601
# 99993   |doorman|elevator|prewar|dogs allowed|cats all...   40.7066
# 99994                                    |hardwood floors   40.8699
#
#         listing_id  longitude      ...      des_capital tele_count  web_count  \
# 10         7211212   -73.9425      ...                0          1          0
# 10000      7150865   -73.9667      ...                0          0          0
# 100004     6887163   -74.0018      ...                0          0          0
# 100007     6888711   -73.9677      ...                1          0          0
# 100013     6934781   -73.9493      ...                0          0          0
# 100014     6894514   -74.0028      ...                0          0          0
# 100016     6930771   -73.9660      ...                0          2          0
# 100020     6867392   -73.9957      ...                3          0          0
# 100026     6898799   -73.9457      ...                0          0          0
# 100027     6814332   -73.9808      ...                0          0          1
# 100030     6869199   -73.9467      ...                0          0          0
# 10004      7102986   -73.9396      ...                1          2          0
# 100044     6895442   -73.9770      ...               69          1          0
# 100048     6846213   -73.9817      ...                2          0          0
# 10005      7089402   -73.9648      ...                3          1          0
# 100051     6889043   -73.9743      ...                5          1          0
# 100052     6913348   -73.9830      ...                0          0          0
# 100053     6894111   -73.9280      ...                5          1          1
# 100055     6900220   -73.9638      ...                0          0          0
# 100058     6848536   -73.9799      ...                0          0          0
# 100062     6858062   -73.9845      ...               14          0          0
# 100063     6836760   -73.9794      ...                1          0          0
# 100065     6866830   -73.9741      ...                0          0          0
# 100066     6885927   -74.0081      ...                9          1          0
# 10007      7120132   -73.9936      ...               98          1          0
# 100071     6933499   -73.9653      ...                9          0          0
# 100075     6921632   -73.9502      ...               21          1          0
# 100076     6913084   -73.9917      ...                1          0          0
# 100079     6907079   -73.9141      ...                0          0          0
# 100081     6925264   -73.9506      ...                0          1          0
# ...            ...        ...      ...              ...        ...        ...
# 99915      6921019   -73.9531      ...                0          0          0
# 99917      6926146   -73.9785      ...                0          0          0
# 99919      6844805   -73.9539      ...               12          2          0
# 99921      6943991   -74.0360      ...               12          1          0
# 99923      6822618   -73.9731      ...                0          0          0
# 99924      6918969   -73.9847      ...                1          0          0
# 99931      6921162   -73.9987      ...                0          0          0
# 99933      6819357   -74.0043      ...               71          1          0
# 99935      6893263   -73.9808      ...                3          0          1
# 99937      6873182   -73.9467      ...                0          1          0
# 9994       7114685   -73.9705      ...                2          0          0
# 99953      6924210   -73.9785      ...                0          0          0
# 99956      6884807   -74.0084      ...                0          0          0
# 99960      6825168   -73.9989      ...                4          0          0
# 99961      6911061   -73.9824      ...               83          1          0
# 99964      6942494   -73.9525      ...               15          1          0
# 99965      6819478   -73.9463      ...                5          0          0
# 99966      6878391   -73.9603      ...                0          1          0
# 99979      6871559   -73.9134      ...                0          0          0
# 99980      6933865   -74.0105      ...                0          0          0
# 99982      6837242   -73.9840      ...               89          0          0
# 99984      6815109   -73.9591      ...                0          0          0
# 99986      6871681   -74.0007      ...                0          0          0
# 99987      6856001   -73.9719      ...                4          1          0
# 99988      6913833   -73.9869      ...                1          1          0
# 9999       7098690   -73.9790      ...               10          1          0
# 99991      6822449   -74.0163      ...                3          1          0
# 99992      6881461   -73.9900      ...                3          0          0
# 99993      6841891   -74.0101      ...                0          0          0
# 99994      6858245   -73.9172      ...                4          1          0
#
#        email_count building_id_exist       date  month  day_of_week  hour  \
# 10               0              True 2016-06-24      6       Friday     7
# 10000            0              True 2016-06-12      6       Sunday    12
# 100004           0              True 2016-04-17      4       Sunday     3
# 100007           0              True 2016-04-18      4       Monday     2
# 100013           0             False 2016-04-28      4     Thursday     1
# 100014           0              True 2016-04-19      4      Tuesday     4
# 100016           2              True 2016-04-27      4    Wednesday     3
# 100020           0              True 2016-04-13      4    Wednesday     6
# 100026           0              True 2016-04-20      4    Wednesday     2
# 100027           0             False 2016-04-02      4     Saturday     2
# 100030           0             False 2016-04-14      4     Thursday     1
# 10004            2             False 2016-06-03      6       Friday     3
# 100044           1              True 2016-04-19      4      Tuesday     5
# 100048           0             False 2016-04-09      4     Saturday     1
# 10005            0             False 2016-06-01      6    Wednesday     3
# 100051           1              True 2016-04-18      4       Monday     2
# 100052           0              True 2016-04-22      4       Friday     5
# 100053           2             False 2016-04-19      4      Tuesday     3
# 100055           0              True 2016-04-20      4    Wednesday     4
# 100058           0              True 2016-04-09      4     Saturday     3
# 100062           0              True 2016-04-12      4      Tuesday     2
# 100063           0              True 2016-04-07      4     Thursday     2
# 100065           0              True 2016-04-13      4    Wednesday     5
# 100066           1              True 2016-04-17      4       Sunday     2
# 10007            1              True 2016-06-07      6      Tuesday     4
# 100071           1              True 2016-04-27      4    Wednesday     6
# 100075           0              True 2016-04-25      4       Monday     2
# 100076           0              True 2016-04-22      4       Friday     5
# 100079           0              True 2016-04-21      4     Thursday     5
# 100081           1              True 2016-04-26      4      Tuesday     2
# ...            ...               ...        ...    ...          ...   ...
# 99915            0             False 2016-04-25      4       Monday     1
# 99917            0              True 2016-04-26      4      Tuesday     4
# 99919            1              True 2016-04-08      4       Friday     5
# 99921            0              True 2016-04-29      4       Friday    15
# 99923            0             False 2016-04-05      4      Tuesday     1
# 99924            1              True 2016-04-24      4       Sunday     3
# 99931            0             False 2016-04-25      4       Monday     1
# 99933            1              True 2016-04-03      4       Sunday     3
# 99935            0             False 2016-04-19      4      Tuesday     2
# 99937            1              True 2016-04-14      4     Thursday     5
# 9994             0             False 2016-06-06      6       Monday     1
# 99953            0              True 2016-04-26      4      Tuesday     2
# 99956            0             False 2016-04-16      4     Saturday    16
# 99960            1              True 2016-04-05      4      Tuesday     4
# 99961            0              True 2016-04-22      4       Friday     3
# 99964            1              True 2016-04-29      4       Friday     5
# 99965            0              True 2016-04-03      4       Sunday     5
# 99966            1              True 2016-04-15      4       Friday     5
# 99979            0              True 2016-04-14      4     Thursday     3
# 99980            0              True 2016-04-27      4    Wednesday    12
# 99982            1              True 2016-04-07      4     Thursday     2
# 99984            0              True 2016-04-02      4     Saturday     3
# 99986            1              True 2016-04-14      4     Thursday     3
# 99987            0             False 2016-04-11      4       Monday     3
# 99988            0              True 2016-04-22      4       Friday    15
# 9999             1              True 2016-06-02      6     Thursday     5
# 99991            1              True 2016-04-04      4       Monday    18
# 99992            0              True 2016-04-16      4     Saturday     2
# 99993            0              True 2016-04-08      4       Friday     2
# 99994            0              True 2016-04-12      4      Tuesday     2
#
#         interest_num
# 10                 2
# 10000              3
# 100004             1
# 100007             3
# 100013             3
# 100014             2
# 100016             3
# 100020             3
# 100026             2
# 100027             3
# 100030             3
# 10004              3
# 100044             1
# 100048             3
# 10005              3
# 100051             2
# 100052             3
# 100053             3
# 100055             3
# 100058             3
# 100062             3
# 100063             2
# 100065             3
# 100066             3
# 10007              2
# 100071             3
# 100075             2
# 100076             3
# 100079             1
# 100081             3
# ...              ...
# 99915              3
# 99917              3
# 99919              2
# 99921              2
# 99923              3
# 99924              3
# 99931              3
# 99933              3
# 99935              3
# 99937              3
# 9994               3
# 99953              3
# 99956              3
# 99960              2
# 99961              3
# 99964              2
# 99965              3
# 99966              3
# 99979              3
# 99980              3
# 99982              1
# 99984              3
# 99986              3
# 99987              3
# 99988              2
# 9999               2
# 99991              3
# 99992              3
# 99993              3
# 99994              3
#
# [49352 rows x 28 columns]

# %%
from collections import Counter
from operator import itemgetter

def popular_featrues(feature_column):
    all_features = ''
    counter = Counter()
    for text in feature_column:
        text = text.split('|')
        all_features = ''.join([all_features, ','.join(text)])
    all_features = all_features.strip(',').split(',')
    #all_features = [item for item in all_features if item != '']
    counter = Counter(all_features)
    popular_features = [k for k, v in sorted(counter.items(), key=itemgetter(1), reverse=True)][:50]
    return popular_features
popular_features = popular_featrues(train_df['features'].values)

# %%
train_df["pop_feature_counts"] = train_df["features"].apply(lambda features: sum(1 for feature in features.split('|') if feature in popular_features))
test_df["pop_feature_counts"] = test_df["features"].apply(lambda features: sum(1 for feature in features.split('|') if feature in popular_features))

# %%
managers = train_df.manager_id.value_counts()
manager_df = train_df.groupby(['manager_id','interest_level']).manager_id.count().unstack('interest_level').fillna(0)
manager_df['sum'] = manager_df.sum(axis=1)
manager_df.sort_values(by='sum',ascending=False)
manager_df['high_rate'] = manager_df['high']/manager_df['sum']
manager_df['medium_rate'] = manager_df['medium']/manager_df['sum']
manager_df['low_rate'] = manager_df['low']/manager_df['sum']

ulimit = np.percentile(manager_df['sum'], 50) #4

high_manager = manager_df[(manager_df['sum']>=4) & (manager_df['high_rate']>0.5)].sort_values(by='high_rate',ascending=False)
medium_manager = manager_df[(manager_df['sum']>=4) & (manager_df['medium_rate']>0.6)].sort_values(by='medium_rate',ascending=False)
low_manager = manager_df[(manager_df['sum']>=4) & (manager_df['low_rate']>0.7)].sort_values(by='low_rate',ascending=False)

# %%
def manager_type(manager_id):
    if manager_id in high_manager.index:
        type = 1
    if manager_id in medium_manager.index:
        type = 2
    if manager_id in low_manager.index:
        type = 3
    else:
        type = 4
    return type
train_df["manager_type"] = train_df["manager_id"].apply(manager_type)
test_df["manager_type"] = test_df["manager_id"].apply(manager_type)

# %%
buildings = train_df.building_id.value_counts()
building_df = train_df.groupby(['building_id', 'interest_level']).building_id.count().unstack('interest_level').fillna(0)
building_df['sum'] = building_df.sum(axis=1)
building_df.sort_values(by='sum',ascending=False)
building_df['high_rate'] = building_df['high']/building_df['sum']
building_df['medium_rate'] = building_df['medium']/building_df['sum']
building_df['low_rate'] = building_df['low']/building_df['sum']

ulimit = np.percentile(building_df['sum'], 70) #3

high_building = building_df[(building_df['sum']>=3) & (building_df['high_rate']>0.6)].sort_values(by='high_rate',ascending=False)
medium_building = building_df[(building_df['sum']>=3) & (building_df['medium_rate']>0.6)].sort_values(by='medium_rate',ascending=False)
low_building = building_df[(building_df['sum']>=3) & (building_df['low_rate']>0.7)].sort_values(by='low_rate',ascending=False)

# %%
def building_type(building_id):
    if building_id in high_building.index:
        type = 1
    if building_id in medium_building.index:
        type = 2
    if building_id in low_building.index:
        type = 3
    else:
        type = 4
    return type
train_df["building_type"] = train_df["building_id"].apply(building_type)
test_df["building_type"] = test_df["building_id"].apply(building_type)

# %%
#write the cleaned test data into a csv file
train_df.to_json('clean_train.json')
test_df.to_json('clean_test.json')
